# %%
import xarray as xr
import os
import matplotlib.pyplot as plt

# %%
# %pwd
# Out:
# '/work/FAC/FGSE/IDYST/tbeucler/downscaling/fquareng/AdaptationSandbox/notebooks'

# %%
data_path = "/work/FAC/FGSE/IDYST/tbeucler/downscaling/fquareng/data"
dem_path = "dem_squares"

# %%
dem = xr.open_dataset(os.path.join(data_path, dem_path, '7_5_dem.nc'))
dem["HSURF"].plot()
